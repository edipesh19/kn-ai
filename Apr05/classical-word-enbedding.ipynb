# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [
    "people watch movie and watch movie again",
    "people watch cricket and watch cricket",
    "people like movie and like movie a lot",
    "people like cricket"
]

# %%
tf_idf = TfidfVectorizer()

# %%
tf_idf_vector = tf_idf.fit_transform(documents)

# %%
for row in tf_idf_vector.toarray():
    print("Row:", row)
# Out:
# Row: [0.38771136 0.24747114 0.         0.         0.         0.61135218
#  0.20232387 0.61135218]
# Row: [0.         0.2684707  0.66322944 0.         0.         0.
#  0.21949239 0.66322944]
# Row: [0.         0.24747114 0.         0.61135218 0.38771136 0.61135218
#  0.20232387 0.        ]
# Row: [0.         0.         0.64043405 0.64043405 0.         0.
#  0.42389674 0.        ]

# %%
tf_idf.get_feature_names_out()
# Out:
# array(['again', 'and', 'cricket', 'like', 'lot', 'movie', 'people',
#        'watch'], dtype=object)

# %% [markdown]
# # Embedding

# %% [markdown]
# ## Classical - Word2vec
